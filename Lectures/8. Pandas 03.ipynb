# %% [markdown]
# # <center> Pandas (part 03) <center>

# %% [markdown]
# <img src = 'https://github.com/saeed-saffari/alzahra-workshop-spr2021/blob/main/lecture/PIC/Pandas.png?raw=true'
#      width = "550"
#      >

# %% [markdown]
# ##  <center> Working with Real data

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ### 1. from Excel, CSV, ...

# %%
os.listdir()
# Out:
# ['API_FP.CPI.TOTL.ZG_DS2_en_excel_v2_174.xls',
#  'time_series_covid19_confirmed_global.csv',
#  '5. Matplotlib.ipynb',
#  'survey_results_public.csv',
#  'world-happiness-report-2021.csv',
#  'Project 01 - Covid19 confirmed cases.ipynb',
#  '1. Introduction to Python (Data Structure).ipynb',
#  'Py for Econ-Intro-SBU Workshop 2025.pdf',
#  'Real GDP Growth (IMF).xlsx',
#  'API_NY.GDP.MKTP.CD_DS2_en_excel_v2_124.xls',
#  '3. Functions.ipynb',
#  '6. Pandas 01.ipynb',
#  '2. Control flow (Loops).ipynb',
#  '7. Pandas 02.ipynb',
#  'Human development index (HDI).xlsx',
#  '.ipynb_checkpoints',
#  'GDP per capita ppp.xlsx',
#  'test_1.png',
#  'Iran GDP growth 1 imf.jpg',
#  '8. Pandas 03.ipynb',
#  '4. NumPy.ipynb']

# %%
inf = pd.read_excel('API_FP.CPI.TOTL.ZG_DS2_en_excel_v2_174.xls')
inf.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2024-12-16 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#                               Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                    NaN             NaN         NaN
# 1                                    NaN             NaN         NaN
# 2                         Indicator Name  Indicator Code      1960.0
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
inf.tail(3)
# Out:
#       Data Source World Development Indicators  \
# 266  South Africa                          ZAF
# 267        Zambia                          ZMB
# 268      Zimbabwe                          ZWE
#
#                                 Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 266  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    1.288859
# 267  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
# 268  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 266    2.102374    1.246285     1.33797    2.534973    4.069029  ...
# 267         NaN         NaN         NaN         NaN         NaN  ...
# 268         NaN         NaN         NaN         NaN         NaN  ...
#
#      Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  \
# 266     6.129838     4.540642     6.571396     5.184247     4.517165
# ...

# %%
inf.shape
# Out:
# (269, 68)

# %%
inf.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2024-12-16 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#                               Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                    NaN             NaN         NaN
# 1                                    NaN             NaN         NaN
# 2                         Indicator Name  Indicator Code      1960.0
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %% [markdown]
# ### 1.2 drop Indices and Columns

# %%
inf.drop([0,1], axis = 0, inplace=True)
inf.head()
# Out:
#                    Data Source World Development Indicators  \
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
# 5                  Afghanistan                          AFG
# 6   Africa Western and Central                          AFW
#
#                               Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 2                         Indicator Name  Indicator Code      1960.0
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
# 5  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
# 6  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 2      1961.0      1962.0      1963.0      1964.0      1965.0  ...
# ...

# %%
inf.columns = inf.iloc[0]

# %%
inf.drop([2], axis = 0, inplace=True)

# %%
inf.head()
# Out:
# 2                 Country Name Country Code  \
# 3                        Aruba          ABW
# 4  Africa Eastern and Southern          AFE
# 5                  Afghanistan          AFG
# 6   Africa Western and Central          AFW
# 7                       Angola          AGO
#
# 2                         Indicator Name  Indicator Code  1960.0  1961.0  \
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG     NaN     NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG     NaN     NaN
# 5  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG     NaN     NaN
# 6  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG     NaN     NaN
# 7  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG     NaN     NaN
#
# 2  1962.0  1963.0  1964.0  1965.0  ...    2014.0    2015.0     2016.0  \
# 3     NaN     NaN     NaN     NaN  ...  0.421441  0.474764  -0.931196
# 4     NaN     NaN     NaN     NaN  ...  5.370290  5.245878   6.571396
# ...

# %%
inf.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                  1960.0,           1961.0,           1962.0,           1963.0,
#                  1964.0,           1965.0,           1966.0,           1967.0,
#                  1968.0,           1969.0,           1970.0,           1971.0,
#                  1972.0,           1973.0,           1974.0,           1975.0,
#                  1976.0,           1977.0,           1978.0,           1979.0,
#                  1980.0,           1981.0,           1982.0,           1983.0,
#                  1984.0,           1985.0,           1986.0,           1987.0,
#                  1988.0,           1989.0,           1990.0,           1991.0,
#                  1992.0,           1993.0,           1994.0,           1995.0,
#                  1996.0,           1997.0,           1998.0,           1999.0,
#                  2000.0,           2001.0,           2002.0,           2003.0,
# ...

# %%
inf = inf.drop(['Country Name', 'Indicator Name', 'Indicator Code'], axis = 1)
inf.head()
# Out:
# 2 Country Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  1966.0  \
# 3          ABW     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4          AFE     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5          AFG     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6          AFW     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7          AGO     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# 2  1967.0  1968.0  ...    2014.0    2015.0     2016.0     2017.0     2018.0  \
# 3     NaN     NaN  ...  0.421441  0.474764  -0.931196  -1.028282   3.626041
# 4     NaN     NaN  ...  5.370290  5.245878   6.571396   6.399343   4.720805
# 5     NaN     NaN  ...  4.673996 -0.661709   4.383892   4.975952   0.626149
# 6     NaN     NaN  ...  1.768436  2.130817   1.487416   1.725486   1.784050
# 7     NaN     NaN  ...  7.280387  9.355972  30.694415  29.844480  19.628938
#
# 2     2019.0     2020.0     2021.0     2022.0     2023.0
# ...

# %% [markdown]
# ### 1.3 change index

# %%
inf.index
# Out:
# RangeIndex(start=3, stop=269, step=1)

# %%
inf.set_index('Country Code', inplace=True)
inf.head()
# Out:
# 2             1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  1966.0  1967.0  \
# Country Code
# ABW              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFE              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFW              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AGO              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# 2             1968.0  1969.0  ...    2014.0    2015.0     2016.0     2017.0  \
# Country Code                  ...
# ABW              NaN     NaN  ...  0.421441  0.474764  -0.931196  -1.028282
# AFE              NaN     NaN  ...  5.370290  5.245878   6.571396   6.399343
# AFG              NaN     NaN  ...  4.673996 -0.661709   4.383892   4.975952
# AFW              NaN     NaN  ...  1.768436  2.130817   1.487416   1.725486
# ...

# %%
inf.columns
# Out:
# Index([1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0,
#        1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0,
#        1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0,
#        1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0,
#        1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0,
#        2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0,
#        2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0, 2022.0,
#        2023.0],
#       dtype='object', name=2)

# %%
np.arange(1960, 2024)
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
inf.columns = np.arange(1960, 2024)

# %%
inf.head()
# Out:
#               1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# Country Code                                                              ...
# ABW            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AFE            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AFG            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AFW            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AGO            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                   2014      2015       2016       2017       2018       2019  \
# Country Code
# ABW           0.421441  0.474764  -0.931196  -1.028282   3.626041   4.257462
# AFE           5.370290  5.245878   6.571396   6.399343   4.720805   4.653665
# AFG           4.673996 -0.661709   4.383892   4.975952   0.626149   2.302373
# AFW           1.768436  2.130817   1.487416   1.725486   1.784050   1.983092
# ...

# %%
inf.columns
# Out:
# Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022, 2023],
#       dtype='int64')

# %%
inf.index
# Out:
# Index(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#        ...
#        'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype='object', name='Country Code', length=266)

# %%
inf.shape
# Out:
# (266, 64)

# %% [markdown]
# ### 1.4 Transpose

# %%
inf.describe()
# Out:
#             1960       1961        1962        1963        1964        1965  \
# count  70.000000  72.000000   74.000000   74.000000   79.000000   86.000000
# mean    3.554980   3.491289    4.630783    5.846612    6.263870    8.192841
# std     6.795697   4.508248   15.209955   17.152509   13.749261   33.376181
# min    -5.030042  -3.900000   -3.846154   -2.694655   -4.535654   -3.878976
# 25%     0.871370   1.468978    1.147323    1.790965    1.870349    1.940405
# 50%     1.945749   2.102977    2.669962    2.898982    3.328408    3.410026
# 75%     4.037155   3.601606    4.614353    4.998460    4.822426    4.938170
# max    39.590444  22.747264  131.397849  145.910781  108.994709  306.763110
#
#               1966        1967        1968        1969  ...        2014  \
# count    93.000000   99.000000  100.000000  101.000000  ...  237.000000
# mean     17.765764    5.496824    6.319736    4.433544  ...    3.646524
# ...

# %%
inf_2 = inf.T
inf_2.head()
# Out:
# Country Code  ABW  AFE  AFG  AFW  AGO  ALB  AND  ARB  ARE  ARG  ...  VIR  VNM  \
# 1960          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1961          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1962          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1963          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1964          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
#
# Country Code  VUT  WLD       WSM  XKX  YEM       ZAF  ZMB  ZWE
# 1960          NaN  NaN       NaN  NaN  NaN  1.288859  NaN  NaN
# 1961          NaN  NaN       NaN  NaN  NaN  2.102374  NaN  NaN
# 1962          NaN  NaN  2.654867  NaN  NaN  1.246285  NaN  NaN
# 1963          NaN  NaN  0.689655  NaN  NaN  1.337970  NaN  NaN
# 1964          NaN  NaN  5.308219  NaN  NaN  2.534973  NaN  NaN
#
# [5 rows x 266 columns]

# %%
inf_2.columns
# Out:
# Index(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#        ...
#        'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype='object', name='Country Code', length=266)

# %%
inf_2.index
# Out:
# Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022, 2023],
#       dtype='int64')

# %%
inf_2.describe()
# Out:
# Country Code        ABW        AFE        AFG        AFW          AGO  \
# count         35.000000  50.000000  15.000000  43.000000    33.000000
# mean           2.957397  10.290417   6.124620   4.649830   337.717693
# std            2.382645   3.738270   7.445406   5.301111   860.721890
# min           -2.372065   4.653665  -6.811161  -0.062999     7.280387
# 25%            1.973815   7.293158   2.240455   1.764670    13.644102
# 50%            3.361391   9.978093   4.975952   3.282440    25.754295
# 75%            4.038140  12.565844   8.033171   5.292342   152.561022
# max            8.955987  19.598394  26.418664  31.841017  4145.105982
#
# Country Code         ALB  AND        ARB        ARE  ARG  ...  VIR        VNM  \
# count          32.000000  0.0  50.000000  16.000000  0.0  ...  0.0  28.000000
# mean           14.739107  NaN   5.664390   2.092970  NaN  ...  NaN   5.682256
# std            41.677892  NaN   3.356595   3.289526  NaN  ...  NaN   5.165227
# ...

# %% [markdown]
# ### 1.5 Plot

# %%
inf_2.head()
# Out:
# Country Code  ABW  AFE  AFG  AFW  AGO  ALB  AND  ARB  ARE  ARG  ...  VIR  VNM  \
# 1960          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1961          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1962          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1963          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1964          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
#
# Country Code  VUT  WLD       WSM  XKX  YEM       ZAF  ZMB  ZWE
# 1960          NaN  NaN       NaN  NaN  NaN  1.288859  NaN  NaN
# 1961          NaN  NaN       NaN  NaN  NaN  2.102374  NaN  NaN
# 1962          NaN  NaN  2.654867  NaN  NaN  1.246285  NaN  NaN
# 1963          NaN  NaN  0.689655  NaN  NaN  1.337970  NaN  NaN
# 1964          NaN  NaN  5.308219  NaN  NaN  2.534973  NaN  NaN
#
# [5 rows x 266 columns]

# %%
inf_2['IRN']
# Out:
# 1960     9.822411
# 1961     3.162564
# 1962     0.721321
# 1963     0.371850
# 1964     3.814490
#           ...
# 2019    39.907346
# 2020    30.594139
# 2021    43.389016
# 2022    43.488464
# 2023    44.579186
# Name: IRN, Length: 64, dtype: float64

# %%
inf_2.plot(y = ['IRN'], figsize = (15,8), lw = 3, c = 'g', fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Inflation (%)', fontsize = 14, fontname = 'Times New Roman')
plt.title('Inflation\nSince 1960', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)


plt.show()

# %%
inf_2.plot(y = ['AUS', 'CAN', 'NOR'], figsize = (15,8), lw = 3, fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Inflation (%)', fontsize = 14, fontname = 'Times New Roman')
plt.title('Inflation\nSince 1960', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)


plt.show()

# %%
inf_2.plot(y = ['IRN','AUS', 'CAN', 'NOR'], figsize = (15,8), lw = 3, fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Inflation (%)', fontsize = 14, fontname = 'Times New Roman')
plt.title('Inflation\nSince 1960', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)


plt.show()

# %%
inf_2.plot(y = ['IRN','AUS', 'CAN', 'NOR', 'BRA'], figsize = (15,8), lw = 3, fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Inflation (%)', fontsize = 14, fontname = 'Times New Roman')
plt.title('Inflation\nSince 1960', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)


plt.show()

# %%
inf_2.plot(y = ['IRN','TUR'], figsize = (15,8), lw = 3, fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Inflation (%)', fontsize = 14, fontname = 'Times New Roman')
plt.title('Inflation\nSince 1960', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)


plt.show()

# %%
inf.head()
# Out:
#               1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# Country Code                                                              ...
# ABW            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AFE            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AFG            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AFW            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# AGO            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                   2014      2015       2016       2017       2018       2019  \
# Country Code
# ABW           0.421441  0.474764  -0.931196  -1.028282   3.626041   4.257462
# AFE           5.370290  5.245878   6.571396   6.399343   4.720805   4.653665
# AFG           4.673996 -0.661709   4.383892   4.975952   0.626149   2.302373
# AFW           1.768436  2.130817   1.487416   1.725486   1.784050   1.983092
# ...

# %%
inf.nlargest(1, 1960).loc[:,1960]
# Out:
# Country Code
# IDN    39.590444
# Name: 1960, dtype: float64

# %%
for i in inf.columns:
    print(inf.nlargest(1, i).loc[:,i])
    print("")
# Out:
# Country Code
# IDN    39.590444
# Name: 1960, dtype: float64
#
# Country Code
# URY    22.747264
# Name: 1961, dtype: float64
#
# Country Code
# IDN    131.397849
# Name: 1962, dtype: float64
#
# Country Code
# IDN    145.910781
# Name: 1963, dtype: float64
#
# Country Code
# IDN    108.994709
# Name: 1964, dtype: float64
#
# Country Code
# IDN    306.76311
# Name: 1965, dtype: float64
#
# Country Code
# IDN    1136.254112
# Name: 1966, dtype: float64
#
# Country Code
# IDN    106.0
# Name: 1967, dtype: float64
#
# Country Code
# IDN    128.843042
# Name: 1968, dtype: float64
#
# Country Code
# ISL    21.763295
# Name: 1969, dtype: float64
#
# Country Code
# URY    16.306145
# Name: 1970, dtype: float64
#
# Country Code
# URY    23.953089
# Name: 1971, dtype: float64
#
# Country Code
# CHL    77.79574
# Name: 1972, dtype: float64
#
# Country Code
# CHL    352.810987
# Name: 1973, dtype: float64
#
# Country Code
# CHL    504.738541
# Name: 1974, dtype: float64
#
# Country Code
# ...

# %% [markdown]
# ## 2. Online data

# %% [markdown]
# ### 2.1 Imports

# %%
# pandas datareader

# %%
#pip install yfinance

# %%
import yfinance as yf
import datetime as dt

# %% [markdown]
# ### 2.2 data reader

# %%
start = dt.datetime(2024, 1, 2)
end = dt.date.today()

price = yf.download('GOOG', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300

# %%
price.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-12-26  197.100006  198.160004  195.869995  196.740005   7907900
# 2024-12-27  194.039993  196.800003  191.972000  196.470001  14693000
# 2024-12-30  192.690002  193.779999  190.360001  190.865005  12209500
# 2024-12-31  190.440002  193.250000  189.580002  192.445007  14355200
# 2025-01-02  190.630005  193.199997  188.710007  191.485001  17518300

# %%
price.columns
# Out:
# MultiIndex([( 'Close', 'GOOG'),
#             (  'High', 'GOOG'),
#             (   'Low', 'GOOG'),
#             (  'Open', 'GOOG'),
#             ('Volume', 'GOOG')],
#            names=['Price', 'Ticker'])

# %%
price.columns = price.columns.droplevel(1)

# %%
price.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300

# %%
price['Volume'].plot(figsize=(15,8), lw = 2)

plt.xlabel('Date', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Valume', fontsize = 14, fontname = 'Times New Roman')
plt.title('Volume timline of GOOGLE', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)

plt.show()

# %%
price[['Open', 'Close']].plot(figsize=(15,8), lw = 2)

plt.xlabel('Date', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Price', fontsize = 14, fontname = 'Times New Roman')
plt.title('Close and Open price timline of GOOGLE', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)

plt.show()

# %%
price[['Open', 'Close']].plot(figsize=(15,8), lw = 2)

plt.xlabel('Date', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Price', fontsize = 14, fontname = 'Times New Roman')
plt.title('Close and Open price timline of GOOGLE', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)

plt.xlim(('2024-02-07', '2024-05-07'))  # NEW

plt.show()

# %%
price.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300

# %%
price.loc['2024-02-07':'2024-05-07', ['Open', 'Close']].plot(figsize=(15,8), lw = 2)

plt.xlabel('Date', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Price', fontsize = 14, fontname = 'Times New Roman')
plt.title('Close and Open price timline of GOOGLE', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)

plt.show()

# %%
price_2 = yf.download(['GOOG', 'AAPL'], start=start, end=end)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
price_2.head()
# Out:
# Price            Close                    High                     Low  \
# Ticker            AAPL        GOOG        AAPL        GOOG        AAPL
# Date
# 2024-01-02  184.734985  139.060333  187.521338  140.111564  182.993517
# 2024-01-03  183.351761  139.857483  184.973819  140.584865  182.535751
# 2024-01-04  181.023163  137.545776  182.197403  140.131487  179.998185
# 2024-01-05  180.296707  136.898117  181.869006  138.313031  179.291637
# 2024-01-08  184.655365  140.026855  184.695178  140.136462  180.615161
#
# Price                         Open                Volume
# Ticker            GOOG        AAPL        GOOG      AAPL      GOOG
# Date
# 2024-01-02  137.246857  186.237618  139.100199  82488700  20071900
# 2024-01-03  137.934385  183.321908  138.103790  58414500  18974300
# 2024-01-04  137.515885  181.261983  139.349309  71983600  18253300
# 2024-01-05  136.360057  181.102771  137.856679  62303300  15433200
# ...

# %%
price_2['Close']['AAPL']
# Out:
# Date
# 2024-01-02    184.734985
# 2024-01-03    183.351761
# 2024-01-04    181.023163
# 2024-01-05    180.296707
# 2024-01-08    184.655365
#                  ...
# 2024-12-26    259.019989
# 2024-12-27    255.589996
# 2024-12-30    252.199997
# 2024-12-31    250.419998
# 2025-01-02    243.850006
# Name: AAPL, Length: 253, dtype: float64

# %%
close_1 = price_2['Close']
close_1
# Out:
# Ticker            AAPL        GOOG
# Date
# 2024-01-02  184.734985  139.060333
# 2024-01-03  183.351761  139.857483
# 2024-01-04  181.023163  137.545776
# 2024-01-05  180.296707  136.898117
# 2024-01-08  184.655365  140.026855
# ...                ...         ...
# 2024-12-26  259.019989  197.100006
# 2024-12-27  255.589996  194.039993
# 2024-12-30  252.199997  192.690002
# 2024-12-31  250.419998  190.440002
# 2025-01-02  243.850006  190.630005
#
# [253 rows x 2 columns]

# %%
(183.351761 - 184.734985) / 184.734985
# Out:
# -0.007487612592709411

# %%
percentage = close_1.pct_change()
percentage
# Out:
# Ticker          AAPL      GOOG
# Date
# 2024-01-02       NaN       NaN
# 2024-01-03 -0.007488  0.005732
# 2024-01-04 -0.012700 -0.016529
# 2024-01-05 -0.004013 -0.004709
# 2024-01-08  0.024175  0.022855
# ...              ...       ...
# 2024-12-26  0.003176 -0.002379
# 2024-12-27 -0.013242 -0.015525
# 2024-12-30 -0.013263 -0.006957
# 2024-12-31 -0.007058 -0.011677
# 2025-01-02 -0.026236  0.000998
#
# [253 rows x 2 columns]

# %%
percentage.plot(figsize=(15,8), lw = 2)

plt.xlabel('Date', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Percentage', fontsize = 14, fontname = 'Times New Roman')
plt.title('GOOGLE and APPLE percentage in price in 2024', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)

plt.show()

# %%
price_2['Close']['GOOG'].pct_change().plot(figsize=(15,8), lw = 2, c = 'g')

plt.xlabel('Date', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Percentage', fontsize = 14, fontname = 'Times New Roman')
plt.title('GOOGLE percentage in price in 2024', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)

plt.show()

# %%
close_1.head()
# Out:
# Ticker            AAPL        GOOG
# Date
# 2024-01-02  184.734985  139.060333
# 2024-01-03  183.351761  139.857483
# 2024-01-04  181.023163  137.545776
# 2024-01-05  180.296707  136.898117
# 2024-01-08  184.655365  140.026855

# %%
183.351761 - 184.734985
# Out:
# -1.3832239999999842

# %%
difference = close_1.diff()
difference
# Out:
# Ticker          AAPL      GOOG
# Date
# 2024-01-02       NaN       NaN
# 2024-01-03 -1.383224  0.797150
# 2024-01-04 -2.328598 -2.311707
# 2024-01-05 -0.726456 -0.647659
# 2024-01-08  4.358658  3.128738
# ...              ...       ...
# 2024-12-26  0.819977 -0.470001
# 2024-12-27 -3.429993 -3.060013
# 2024-12-30 -3.389999 -1.349991
# 2024-12-31 -1.779999 -2.250000
# 2025-01-02 -6.569992  0.190002
#
# [253 rows x 2 columns]

# %%
difference.plot(figsize=(15,8), lw = 2)

plt.xlabel('Date', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('Difference', fontsize = 14, fontname = 'Times New Roman')
plt.title('GOOGLE and APPLE Difference in price in 2024', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(fontsize = 12)

plt.show()

# %%
price.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300

# %%
price.Close
# Out:
# Date
# 2024-01-02    139.060333
# 2024-01-03    139.857483
# 2024-01-04    137.545776
# 2024-01-05    136.898117
# 2024-01-08    140.026855
#                  ...
# 2024-12-26    197.100006
# 2024-12-27    194.039993
# 2024-12-30    192.690002
# 2024-12-31    190.440002
# 2025-01-02    190.630005
# Name: Close, Length: 253, dtype: float64

# %%
price.Close.shift(1)
# Out:
# Date
# 2024-01-02           NaN
# 2024-01-03    139.060333
# 2024-01-04    139.857483
# 2024-01-05    137.545776
# 2024-01-08    136.898117
#                  ...
# 2024-12-26    197.570007
# 2024-12-27    197.100006
# 2024-12-30    194.039993
# 2024-12-31    192.690002
# 2025-01-02    190.440002
# Name: Close, Length: 253, dtype: float64

# %% [markdown]
# $$ Log_return= log(\frac{Price_{t+1}}{Price_t})$$
# $$ Log_return= log(\frac{Price_{t}}{Price_{t-1}})$$

# %%
np.log(139.857483 / 139.060333)
# Out:
# np.float64(0.005716036227987908)

# %%
price['lg_return'] = np.log(price.Close / price.Close.shift(1))
price.head()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300
#
# Price       lg_return
# Date
# 2024-01-02        NaN
# 2024-01-03   0.005716
# 2024-01-04  -0.016667
# 2024-01-05  -0.004720
# 2024-01-08   0.022597

# %%
price.Close
# Out:
# Date
# 2024-01-02    139.060333
# 2024-01-03    139.857483
# 2024-01-04    137.545776
# 2024-01-05    136.898117
# 2024-01-08    140.026855
#                  ...
# 2024-12-26    197.100006
# 2024-12-27    194.039993
# 2024-12-30    192.690002
# 2024-12-31    190.440002
# 2025-01-02    190.630005
# Name: Close, Length: 253, dtype: float64

# %%
(139.060333 + 139.857483) / 2
# Out:
# 139.458908

# %%
(137.545776 + 139.857483) / 2
# Out:
# 138.7016295

# %%
(139.060333 + 139.857483 + 137.545776) / 3
# Out:
# 138.82119733333334

# %%
price.Close.rolling(10).mean().head(15)
# Out:
# Date
# 2024-01-02           NaN
# 2024-01-03           NaN
# 2024-01-04           NaN
# 2024-01-05           NaN
# 2024-01-08           NaN
# 2024-01-09           NaN
# 2024-01-10           NaN
# 2024-01-11           NaN
# 2024-01-12           NaN
# 2024-01-16    140.916673
# 2024-01-17    141.248482
# 2024-01-18    141.709824
# 2024-01-19    142.699268
# 2024-01-22    143.727574
# 2024-01-23    144.539658
# Name: Close, dtype: float64

# %%
price['MA10'] = price.Close.rolling(10).mean()
price
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300
# ...                ...         ...         ...         ...       ...
# 2024-12-26  197.100006  198.160004  195.869995  196.740005   7907900
# 2024-12-27  194.039993  196.800003  191.972000  196.470001  14693000
# 2024-12-30  192.690002  193.779999  190.360001  190.865005  12209500
# 2024-12-31  190.440002  193.250000  189.580002  192.445007  14355200
# 2025-01-02  190.630005  193.199997  188.710007  191.485001  17518300
#
# Price       lg_return        MA10
# Date
# 2024-01-02        NaN         NaN
# 2024-01-03   0.005716         NaN
# ...

# %%
plt.figure(figsize=(12,8))
plt.plot(price.index, price.Close, lw = 2, c = 'b', label = 'Close Price')
plt.plot(price.index, price.MA10, lw = 2, c = 'r', label = 'Close Price')
plt.legend()
plt.grid()
plt.show()

# %%
price['diff'] = price.High - price.Low
price.head()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300
#
# Price       lg_return  MA10      diff
# Date
# 2024-01-02        NaN   NaN  2.864707
# 2024-01-03   0.005716   NaN  2.650480
# 2024-01-04  -0.016667   NaN  2.615602
# 2024-01-05  -0.004720   NaN  1.952974
# 2024-01-08   0.022597   NaN  2.750113

# %%
price[['diff', 'Volume']].corr()
# Out:
# Price       diff    Volume
# Price
# diff    1.000000  0.491839
# Volume  0.491839  1.000000

# %% [markdown]
# | Symbols | Company |
# |---      | ---     |
# |INTC| Intel|
# |MSFT| Microsoft|
# |IBM| IBM|
# |BHP| BHP|
# |TM| Toyota|
# |AAPL| Apple|
# |AMZN| Amazon|
# |BA| Boeing|
# |QCOM| Qualcomm|
# |KO| Coca-Cola|
# |GOOG| Google|
# |SNE| Sony|
# |PTR| PetroChina|

# %% [markdown]
# ## 3. Extra Work

# %%
price_AAPL = yf.download('AAPL', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price_AAPL.columns = price_AAPL.columns.droplevel(1)
price_AAPL.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2024-01-02  184.734985  187.521338  182.993517  186.237618  82488700
# 2024-01-03  183.351761  184.973819  182.535751  183.321908  58414500
# 2024-01-04  181.023163  182.197403  179.998185  181.261983  71983600
# 2024-01-05  180.296707  181.869006  179.291637  181.102771  62303300
# 2024-01-08  184.655365  184.695178  180.615161  181.202281  59144500

# %%
price_AAPL['daily_diffrence'] = price_AAPL['Close'].diff()
price_AAPL.head()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2024-01-02  184.734985  187.521338  182.993517  186.237618  82488700
# 2024-01-03  183.351761  184.973819  182.535751  183.321908  58414500
# 2024-01-04  181.023163  182.197403  179.998185  181.261983  71983600
# 2024-01-05  180.296707  181.869006  179.291637  181.102771  62303300
# 2024-01-08  184.655365  184.695178  180.615161  181.202281  59144500
#
# Price       daily_diffrence
# Date
# 2024-01-02              NaN
# 2024-01-03        -1.383224
# 2024-01-04        -2.328598
# 2024-01-05        -0.726456
# 2024-01-08         4.358658

# %%
price_AAPL['signal'] = np.where(price_AAPL['daily_diffrence'] > 0, 1, 0)
price_AAPL.head(10)
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2024-01-02  184.734985  187.521338  182.993517  186.237618  82488700
# 2024-01-03  183.351761  184.973819  182.535751  183.321908  58414500
# 2024-01-04  181.023163  182.197403  179.998185  181.261983  71983600
# 2024-01-05  180.296707  181.869006  179.291637  181.102771  62303300
# 2024-01-08  184.655365  184.695178  180.615161  181.202281  59144500
# 2024-01-09  184.237411  184.247357  181.839157  183.023358  42841800
# 2024-01-10  185.282303  185.491271  183.023365  183.451277  46792900
# 2024-01-11  184.685211  186.138100  182.724814  185.630577  49128400
# 2024-01-12  185.013596  185.829605  184.287159  185.152912  40444700
# 2024-01-16  182.734787  183.361705  180.047938  181.271952  65603000
#
# Price       daily_diffrence  signal
# Date
# 2024-01-02              NaN       0
# 2024-01-03        -1.383224       0
# 2024-01-04        -2.328598       0
# 2024-01-05        -0.726456       0
# ...

# %%
price_AAPL['position'] = price_AAPL['signal'].diff()
price_AAPL.head(10)
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2024-01-02  184.734985  187.521338  182.993517  186.237618  82488700
# 2024-01-03  183.351761  184.973819  182.535751  183.321908  58414500
# 2024-01-04  181.023163  182.197403  179.998185  181.261983  71983600
# 2024-01-05  180.296707  181.869006  179.291637  181.102771  62303300
# 2024-01-08  184.655365  184.695178  180.615161  181.202281  59144500
# 2024-01-09  184.237411  184.247357  181.839157  183.023358  42841800
# 2024-01-10  185.282303  185.491271  183.023365  183.451277  46792900
# 2024-01-11  184.685211  186.138100  182.724814  185.630577  49128400
# 2024-01-12  185.013596  185.829605  184.287159  185.152912  40444700
# 2024-01-16  182.734787  183.361705  180.047938  181.271952  65603000
#
# Price       daily_diffrence  signal  position
# Date
# 2024-01-02              NaN       0       NaN
# 2024-01-03        -1.383224       0       0.0
# 2024-01-04        -2.328598       0       0.0
# ...

# %%
price_AAPL[price_AAPL['position']==1].index
# Out:
# DatetimeIndex(['2024-01-08', '2024-01-10', '2024-01-12', '2024-01-18',
#                '2024-02-01', '2024-02-05', '2024-02-09', '2024-02-21',
#                '2024-02-27', '2024-03-08', '2024-03-14', '2024-03-18',
#                '2024-03-22', '2024-03-27', '2024-04-03', '2024-04-05',
#                '2024-04-09', '2024-04-11', '2024-04-22', '2024-04-29',
#                '2024-05-02', '2024-05-07', '2024-05-13', '2024-05-24',
#                '2024-06-07', '2024-06-11', '2024-06-17', '2024-06-24',
#                '2024-07-01', '2024-07-12', '2024-07-19', '2024-07-23',
#                '2024-07-26', '2024-08-02', '2024-08-07', '2024-08-20',
#                '2024-08-23', '2024-08-29', '2024-09-05', '2024-09-09',
#                '2024-09-11', '2024-09-17', '2024-09-24', '2024-09-26',
#                '2024-10-02', '2024-10-04', '2024-10-08', '2024-10-14',
#                '2024-10-17', '2024-10-25', '2024-11-05', '2024-11-07',
# ...

# %%
price_AAPL.loc[price_AAPL['position']==1, 'Close']
# Out:
# Date
# 2024-01-08    184.655365
# 2024-01-10    185.282303
# 2024-01-12    185.013596
# 2024-01-18    187.710388
# 2024-02-01    185.949036
# 2024-02-05    186.765015
# 2024-02-09    188.169144
# 2024-02-21    181.662689
# 2024-02-27    181.971558
# 2024-03-08    170.114456
# 2024-03-14    172.376266
# 2024-03-18    173.093689
# 2024-03-22    171.658875
# 2024-03-27    172.685165
# 2024-04-03    169.038345
# 2024-04-05    168.968597
# 2024-04-09    169.058273
# 2024-04-11    174.408920
# 2024-04-22    165.242096
# 2024-04-29    172.874466
# 2024-05-02    172.406174
# 2024-05-07    181.742386
# 2024-05-13    185.860138
# 2024-05-24    189.551804
# 2024-06-07    196.446228
# 2024-06-11    206.683105
# 2024-06-17    216.181656
# 2024-06-24    207.670883
# 2024-07-01    216.261475
# 2024-07-12    230.020386
# 2024-07-19    223.804428
# 2024-07-23    224.502853
# 2024-07-26    217.468750
# 2024-08-02    219.364471
# 2024-08-07    209.347107
# 2024-08-20    226.261063
# ...

# %%
plt.figure(figsize=(15,8))

plt.plot(price_AAPL['Close'], c = 'r', lw = 2)
plt.plot(price_AAPL[price_AAPL['position']==1].index,
         price_AAPL.loc[price_AAPL['position']==1, 'Close'], 'o', c = 'g', markersize = 7
        )

plt.plot(price_AAPL[price_AAPL['position']==-1].index,
         price_AAPL.loc[price_AAPL['position']==-1, 'Close'], 'x', c = 'k', markersize = 7
        )

plt.grid()
plt.show()

# %% [markdown]
# ## 4. World Bank

# %% [markdown]
# ### 4.1 Imports

# %%
# pip install wbgapi

# %%
import wbgapi as wb

# %%
#wb.region.info()
#wb.time.info()
#wb.source.info()
#wb.economy.info()

# %%
wb.region.members('MNA')
# Out:
# {'DJI',
#  'DZA',
#  'EGY',
#  'IRN',
#  'IRQ',
#  'JOR',
#  'LBN',
#  'LBY',
#  'MAR',
#  'PSE',
#  'SYR',
#  'TUN',
#  'YEM'}

# %%
inf = wb.data.DataFrame(series='FP.CPI.TOTL.ZG', 
                       economy='all',
                       time='all', numericTimeKeys=True,
                       labels=True # for show Country name
                       )
inf.head()
# Out:
#                        Country  1960  1961  1962  1963  1964  1965  1966  \
# economy
# ZWE                   Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ZMB                     Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# YEM                Yemen, Rep.   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# PSE         West Bank and Gaza   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# VIR      Virgin Islands (U.S.)   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#          1967  1968  ...      2014       2015       2016      2017       2018  \
# economy              ...
# ZWE       NaN   NaN  ... -0.197785  -2.430968  -1.543670  0.893962  10.618866
# ZMB       NaN   NaN  ...  7.806876  10.110593  17.869730  6.577312   7.494572
# YEM       NaN   NaN  ...  8.104726        NaN        NaN       NaN        NaN
# PSE       NaN   NaN  ...  1.732985   1.431611  -0.219107  0.212571  -0.195108
# VIR       NaN   NaN  ...       NaN        NaN        NaN       NaN        NaN
#
# ...

# %%
inf2 = inf.set_index('Country').sort_index()
inf2.head()
# Out:
#                              1960  1961  1962  1963  1964  1965  1966  1967  \
# Country
# Afghanistan                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Western and Central    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria                       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                              1968  1969  ...      2014      2015      2016  \
# Country                                  ...
# Afghanistan                   NaN   NaN  ...  4.673996 -0.661709  4.383892
# Africa Eastern and Southern   NaN   NaN  ...  5.370290  5.245878  6.571396
# Africa Western and Central    NaN   NaN  ...  1.768436  2.130817  1.487416
# Albania                       NaN   NaN  ...  1.625865  1.896174  1.275432
# Algeria                       NaN   NaN  ...  2.916927  4.784447  6.397695
#
# ...

# %%
inf3 = inf2.T
inf3.head()
# Out:
# Country  Afghanistan  Africa Eastern and Southern  Africa Western and Central  \
# 1960             NaN                          NaN                         NaN
# 1961             NaN                          NaN                         NaN
# 1962             NaN                          NaN                         NaN
# 1963             NaN                          NaN                         NaN
# 1964             NaN                          NaN                         NaN
#
# Country  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960         NaN      NaN             NaN      NaN     NaN
# 1961         NaN      NaN             NaN      NaN     NaN
# 1962         NaN      NaN             NaN      NaN     NaN
# 1963         NaN      NaN             NaN      NaN     NaN
# 1964         NaN      NaN             NaN      NaN     NaN
#
# Country  Antigua and Barbuda  Arab World  ...  Uzbekistan  Vanuatu  \
# 1960                     NaN         NaN  ...         NaN      NaN
# ...

# %%
inf3['Iran, Islamic Rep.'].plot()

plt.show()

# %%
wb.data.DataFrame('NE.EXP.GNFS.CD', 
                 economy=wb.region.members('MNA'),
                 time='all', numericTimeKeys=True,
                  labels=True
                 ).set_index('Country').T.plot(figsize=(15,8),lw = 2)

plt.grid()
plt.show()

# %% [markdown]
# ## 5. Statemodel

# %% [markdown]
# ## 5.1

# %%
#pip install statsmodels

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
data = sm.datasets.longley.load_pandas().data
data.head()
# Out:
#     TOTEMP  GNPDEFL       GNP   UNEMP   ARMED       POP    YEAR
# 0  60323.0     83.0  234289.0  2356.0  1590.0  107608.0  1947.0
# 1  61122.0     88.5  259426.0  2325.0  1456.0  108632.0  1948.0
# 2  60171.0     88.2  258054.0  3682.0  1616.0  109773.0  1949.0
# 3  61187.0     89.5  284599.0  3351.0  1650.0  110929.0  1950.0
# 4  63221.0     96.2  328975.0  2099.0  3099.0  112075.0  1951.0

# %%
data.columns
# Out:
# Index(['TOTEMP', 'GNPDEFL', 'GNP', 'UNEMP', 'ARMED', 'POP', 'YEAR'], dtype='object')

# %%
y = data['TOTEMP']
X = data[['GNPDEFL', 'GNP', 'UNEMP', 'ARMED', 'POP', 'YEAR']]

# %%
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 TOTEMP   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     330.3
# Date:                Fri, 03 Jan 2025   Prob (F-statistic):           4.98e-10
# Time:                        08:34:57   Log-Likelihood:                -109.62
# No. Observations:                  16   AIC:                             233.2
# Df Residuals:                       9   BIC:                             238.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.482e+06    8.9e+05     -3.911      0.004    -5.5e+06   -1.47e+06
# ...

# %% [markdown]
# ## 5.2

# %%
price.head()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2024-01-02  139.060333  140.111564  137.246857  139.100199  20071900
# 2024-01-03  139.857483  140.584865  137.934385  138.103790  18974300
# 2024-01-04  137.545776  140.131487  137.515885  139.349309  18253300
# 2024-01-05  136.898117  138.313031  136.360057  137.856679  15433200
# 2024-01-08  140.026855  140.136462  137.386349  137.505915  17645300
#
# Price       lg_return  MA10      diff
# Date
# 2024-01-02        NaN   NaN  2.864707
# 2024-01-03   0.005716   NaN  2.650480
# 2024-01-04  -0.016667   NaN  2.615602
# 2024-01-05  -0.004720   NaN  1.952974
# 2024-01-08   0.022597   NaN  2.750113

# %%
y = price['Volume']
X = price['Close']

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Volume   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     11.18
# Date:                Fri, 03 Jan 2025   Prob (F-statistic):           0.000955
# Time:                        08:36:46   Log-Likelihood:                -4383.6
# No. Observations:                 253   AIC:                             8771.
# Df Residuals:                     251   BIC:                             8778.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.78e+07   5.44e+06      6.948      0.000    2.71e+07    4.85e+07
# ...

# %%
import wbdata

# %%
countries = ['USA', 'CHN']
indicator = {"NY.GDP.PCAP.CD": "GDP per capita", "SP.DYN.LE00.IN": "Life expectancy"}
data_date = (pd.to_datetime('2010'), pd.to_datetime('2020'))

data = wbdata.get_dataframe(indicator, country=countries)
data.head()
# Out:
#               GDP per capita  Life expectancy
# country date
# China   2023    12614.061742              NaN
#         2022    12662.582671           78.587
#         2021    12617.505104           78.211
#         2020    10408.719554           78.077
#         2019    10143.860221           77.968

# %%
data.dropna(inplace=True)

# %%
data['Log GDP per capita'] = np.log(data['GDP per capita'])

# %%
data.head()
# Out:
#               GDP per capita  Life expectancy  Log GDP per capita
# country date
# China   2022    12662.582671           78.587            9.446407
#         2021    12617.505104           78.211            9.442840
#         2020    10408.719554           78.077            9.250399
#         2019    10143.860221           77.968            9.224624
#         2018     9905.406383           77.744            9.200836

# %%
X = sm.add_constant(data['Log GDP per capita'])
y = data['Life expectancy']

ols_model = sm.OLS(y, X).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Life expectancy   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                     328.6
# Date:                Fri, 03 Jan 2025   Prob (F-statistic):           1.15e-36
# Time:                        08:42:03   Log-Likelihood:                -361.91
# No. Observations:                 126   AIC:                             727.8
# Df Residuals:                     124   BIC:                             733.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 44.9118      1.481     30.332      0.000      41.981      47.842
# ...

# %%
data.columns = ['GDP_per_capita', 'Life_expectancy', 'Log_GDP_per_apita']

# %%
data.head()
# Out:
#               GDP_per_capita  Life_expectancy  Log_GDP_per_apita
# country date
# China   2022    12662.582671           78.587           9.446407
#         2021    12617.505104           78.211           9.442840
#         2020    10408.719554           78.077           9.250399
#         2019    10143.860221           77.968           9.224624
#         2018     9905.406383           77.744           9.200836

# %%
model = smf.ols('Life_expectancy ~ np.log(GDP_per_capita)', data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_expectancy   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                     328.6
# Date:                Fri, 03 Jan 2025   Prob (F-statistic):           1.15e-36
# Time:                        08:44:58   Log-Likelihood:                -361.91
# No. Observations:                 126   AIC:                             727.8
# Df Residuals:                     124   BIC:                             733.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 44.9118      1.481     30.332      0.000      41.981      47.842
# ...
